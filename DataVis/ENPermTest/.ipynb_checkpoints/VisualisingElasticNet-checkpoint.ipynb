# %% [markdown]
# Notebook to produce charts for the elastic net permutation test for information content.

# %%
# intial  imports

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Dark2')
import os

# %%
mypath = 'C:/Users/Tim/Documents/Nuffield/MphilThesis/DataVis/ENPermTest/Figs/'

# %%
# Import data referring to entire data run of code
nonzerocoeffs_entire = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/Entire/nonzerocoeffs.npy')
# in the order: stdev, skew, kurt
nonzerocoeffs_entire_mean = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/Mean/Entire/nonzerocoeffs.npy')

mean_entire = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/Mean/Entire/mean_entire.npy')
stdev_entire = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/Entire/stdev_entire.npy')
skew_entire = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/Entire/skew_entire.npy')
kurt_entire = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/Entire/kurt_entire.npy')

# %%
# Import the number of non zero coeffs chosen by elastic net

nonzerocoeffs = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/nonzerocoeffs.npy')
# This is the number of non zero coefficients. They are ordered:
    # st dev ir
    # st dev qa
    # st dev stat
    # skew ir
    # skew qa
    # skew stat
    # kurt ir
    # kurt qa
    # kurt stat

# %%
# Import the  same for the mean
nonzerocoeffs_mean = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/Mean/nonzerocoeffs.npy')

# %%
# Import the permutations data

mean_ir = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/Mean/mean_ir.npy')
mean_qa = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/Mean/mean_qa.npy')
mean_stat = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/Mean/mean_stat.npy')

stdev_ir = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/stdev_ir.npy')
stdev_qa = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/stdev_qa.npy')
stdev_stat = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/stdev_stat.npy')

skew_ir = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/skew_ir.npy')
skew_qa = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/skew_qa.npy')
skew_stat = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/skew_stat.npy')


kurt_ir = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/kurt_ir.npy')
kurt_qa = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/kurt_qa.npy')
kurt_stat = np.load('C:/Users/Tim/Documents/Nuffield/MphilThesis/Output/4 - VariableSelection/1 - Permutation/Together/k_30/QuerySeparate/kurt_stat.npy')

# %%
# Plot when using entire data

plt.figure(figsize=(20, 6))

# Mean
plt.subplot(1, 3, 1)
plt.hist(mean_entire, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_entire_mean[0], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.legend(loc='best')
plt.title('Mean')


# StDev
plt.subplot(1, 3, 2)
plt.hist(stdev_entire, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_entire[0], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('StDev')
plt.legend(loc='best')

# Skew
plt.subplot(1, 3, 3)
plt.hist(skew_entire, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_entire[1], color='k', linestyle='dashed', label = 'No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('Skew')
plt.legend(loc='best')


plt.savefig(mypath+str('ENPermEntire.pdf'))

plt.show()

# %%
# Plot for StDev

plt.figure(figsize=(20, 6))

# IR
plt.subplot(1, 3, 1)
plt.hist(stdev_ir, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs[0], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('IR')
plt.legend(loc='best')

# QA
plt.subplot(1, 3, 2)
plt.hist(stdev_qa, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs[1], color='k', linestyle='dashed', label = 'No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('Q and A')
plt.legend(loc='best')

# Stat
plt.subplot(1, 3, 3)
plt.hist(stdev_stat, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs[2], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.legend(loc='best')
plt.title('Statement')

plt.savefig(mypath+str('ENPermStDev.pdf'))

plt.show()

# %%
# Plot for Skew

#Do the plot

plt.figure(figsize=(20, 6))

# IR
plt.subplot(1, 3, 1)
plt.hist(skew_ir, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs[3], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('IR')
plt.legend(loc='best')

# QA
plt.subplot(1, 3, 2)
plt.hist(skew_qa, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs[4], color='k', linestyle='dashed', label = 'No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('Q and A')
plt.legend(loc='best')

# Stat
plt.subplot(1, 3, 3)
plt.hist(skew_stat, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs[5], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.legend(loc='best')
plt.title('Statement')

plt.savefig(mypath+str('ENPermSkew.pdf'))

plt.show()
