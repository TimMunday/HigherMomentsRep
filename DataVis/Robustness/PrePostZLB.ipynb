# %% [markdown]
# Notebook for producing EN test charts when the sample is split across the ZLB date.

# %%
# import some packages
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Dark2')
import os
directory = 'C:/Users/tmund/Documents/Submissions/HigherMomentsRep/'
os.chdir(directory)

# %%
mypath = 'DataVis/Robustness/Figs/'

# %%
# Import data

nonzerocoeffs_pre = np.load('Output/5 - Robustness/Purged/PreZLB/nonzerocoeffs.npy')
nonzerocoeffs_post = np.load('Output/5 - Robustness/Purged/PostZLB/nonzerocoeffs.npy')

mean_ir_pre = np.load('Output/5 - Robustness/Purged/PreZLB/mean_ir.npy')
mean_qa_pre = np.load('Output/5 - Robustness/Purged/PreZLB/mean_qa.npy')
mean_stat_pre = np.load('Output/5 - Robustness/Purged/PreZLB/mean_stat.npy')
stdev_ir_pre = np.load('Output/5 - Robustness/Purged/PreZLB/stdev_ir.npy')
stdev_qa_pre = np.load('Output/5 - Robustness/Purged/PreZLB/stdev_qa.npy')
stdev_stat_pre = np.load('Output/5 - Robustness/Purged/PreZLB/stdev_stat.npy')
skew_ir_pre = np.load('Output/5 - Robustness/Purged/PreZLB/skew_ir.npy')
skew_qa_pre = np.load('Output/5 - Robustness/Purged/PreZLB/skew_qa.npy')
skew_stat_pre = np.load('Output/5 - Robustness/Purged/PreZLB/skew_stat.npy')

mean_ir_post = np.load('Output/5 - Robustness/Purged/PostZLB/mean_ir.npy')
mean_qa_post = np.load('Output/5 - Robustness/Purged/PostZLB/mean_qa.npy')
mean_stat_post = np.load('Output/5 - Robustness/Purged/PostZLB/mean_stat.npy')
stdev_ir_post = np.load('Output/5 - Robustness/Purged/PostZLB/stdev_ir.npy')
stdev_qa_post = np.load('Output/5 - Robustness/Purged/PostZLB/stdev_qa.npy')
stdev_stat_post = np.load('Output/5 - Robustness/Purged/PostZLB/stdev_stat.npy')
skew_ir_post = np.load('Output/5 - Robustness/Purged/PostZLB/skew_ir.npy')
skew_qa_post = np.load('Output/5 - Robustness/Purged/PostZLB/skew_qa.npy')
skew_stat_post = np.load('Output/5 - Robustness/Purged/PostZLB/skew_stat.npy')

nonzerocoeffs_entire_pre = np.load('Output/5 - Robustness/Purged/PreZLB/Entire/nonzerocoeffs.npy')
nonzerocoeffs_entire_post = np.load('Output/5 - Robustness/Purged/PostZLB/Entire/nonzerocoeffs.npy')

mean_entire_pre = np.load('Output/5 - Robustness/Purged/PreZLB/Entire/mean_entire.npy')
stdev_entire_pre = np.load('Output/5 - Robustness/Purged/PreZLB/Entire/stdev_entire.npy')
skew_entire_pre = np.load('Output/5 - Robustness/Purged/PreZLB/Entire/skew_entire.npy')

mean_entire_post = np.load('Output/5 - Robustness/Purged/PostZLB/Entire/mean_entire.npy')
stdev_entire_post = np.load('Output/5 - Robustness/Purged/PostZLB/Entire/stdev_entire.npy')
skew_entire_post = np.load('Output/5 - Robustness/Purged/PostZLB/Entire/skew_entire.npy')

# %%
# Plot for second moment pre zlb

plt.figure(figsize=(20, 6))

# IR
plt.subplot(1, 3, 1)
plt.hist(stdev_ir_pre, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_pre[3], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('IR')
plt.legend(loc='best')

# QA
plt.subplot(1, 3, 2)
plt.hist(stdev_qa_pre, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_pre[4], color='k', linestyle='dashed', label = 'No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('Q and A')
plt.legend(loc='best')

# Stat
plt.subplot(1, 3, 3)
plt.hist(stdev_stat_pre, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_pre[5], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.legend(loc='best')
plt.title('Statement')

plt.savefig(mypath+str('ENPermStDevPreZLB.pdf'))

plt.show()

# %%
# Plot for second moment post zlb


plt.figure(figsize=(20, 6))

# IR
plt.subplot(1, 3, 1)
plt.hist(stdev_ir_post, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_post[3], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('IR')
plt.legend(loc='best')

# QA
plt.subplot(1, 3, 2)
plt.hist(stdev_qa_post, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_post[4], color='k', linestyle='dashed', label = 'No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('Q and A')
plt.legend(loc='best')

# Stat
plt.subplot(1, 3, 3)
plt.hist(stdev_stat_post, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_post[5], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.legend(loc='best')
plt.title('Statement')

plt.savefig(mypath+str('ENPermStDevPostZLB.pdf'))

plt.show()

# %%
# Plot for Skew pre

plt.figure(figsize=(20, 6))

# IR
plt.subplot(1, 3, 1)
plt.hist(skew_ir_pre, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_pre[6], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('IR')
plt.legend(loc='best')

# QA
plt.subplot(1, 3, 2)
plt.hist(skew_qa_pre, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_pre[7], color='k', linestyle='dashed', label = 'No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('Q and A')
plt.legend(loc='best')

# Stat
plt.subplot(1, 3, 3)
plt.hist(skew_stat_pre, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_pre[8], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.legend(loc='best')
plt.title('Statement')

plt.savefig(mypath+str('ENPermSkewPreZLB.pdf'))

plt.show()

# %%
# Plot for Skew post

plt.figure(figsize=(20, 6))

# IR
plt.subplot(1, 3, 1)
plt.hist(skew_ir_post, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_post[6], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('IR')
plt.legend(loc='best')

# QA
plt.subplot(1, 3, 2)
plt.hist(skew_qa_post, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_post[7], color='k', linestyle='dashed', label = 'No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.title('Q and A')
plt.legend(loc='best')

# Stat
plt.subplot(1, 3, 3)
plt.hist(skew_stat_post, bins=20, label='Distribution of topics chosen under permutation')
plt.axvline(nonzerocoeffs_post[8], color='k', linestyle='dashed', label='No. of topics chosen using correct sample')
plt.xlabel('Number of topics selected by Elastic Net')
plt.ylabel('Frequency')
plt.legend(loc='best')
plt.title('Statement')

plt.savefig(mypath+str('ENPermSkewPostZLB.pdf'))

plt.show()
